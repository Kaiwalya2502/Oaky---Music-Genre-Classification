# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)

# %%
# !mkdir .kaggle
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
import json
token = {'username':'kaiwalyashukla','key':'e068fd8e65fff480811edca67b722572'}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d andradaolteanu/gtzan-dataset-music-genre-classification
# Out:
# Downloading gtzan-dataset-music-genre-classification.zip to {/content}/datasets/andradaolteanu/gtzan-dataset-music-genre-classification
#  99% 1.20G/1.21G [00:30<00:00, 68.4MB/s]
# 100% 1.21G/1.21G [00:30<00:00, 42.2MB/s]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os, json, math, librosa

import IPython.display as ipd
import librosa.display

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D

import sklearn.model_selection as sk

from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import zipfile

file = zipfile.ZipFile("/content/{/content}/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/gtzan-dataset-music-genre-classification.zip","r")
file.extractall('/tmp')
file.close()

# %%
MUSIC = '/tmp/Data/genres_original'
music_dataset = [] # File locations for each wav file 
genre_target = []  
for root, dirs, files in os.walk(MUSIC):
    for name in files:
        filename = os.path.join(root, name)
        if filename != '/tmp/Data/genres_original/jazz/jazz.00054.wav':
            music_dataset.append(filename)
            genre_target.append(filename.split("/")[4])

# %%
set(genre_target)
# Out:
# {'blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock'}

# %%
audio_path = music_dataset[500]

x , sr = librosa.load(audio_path)

librosa.load(audio_path, sr=None)

ipd.Audio(audio_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(16, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.title('Spectogram')
plt.colorbar()

# %%
file_location = audio_path
y, sr = librosa.load(file_location)
melSpec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
melSpec_dB = librosa.power_to_db(melSpec, ref=np.max)
plt.figure(figsize=(10, 5))
librosa.display.specshow(melSpec_dB, x_axis='time', y_axis='mel', sr=sr, fmax=8000)
plt.colorbar(format='%+1.0f dB')
plt.title("MelSpectrogram")
plt.tight_layout()
plt.show()

# %%
DATASET_PATH = '/tmp/Data/genres_original/'
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file

                file_path = os.path.join(dirpath, f)
            
                if file_path != '/tmp/Data/genres_original/jazz/jazz.00054.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                
                
                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
# Out:
# Streaming output truncated to the last 5000 lines.
# /tmp/Data/genres_original/reggae/reggae.00084.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00084.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00084.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00084.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00084.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00060.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00090.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00046.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00024.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00047.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00030.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00016.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00094.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00083.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00003.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00010.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00081.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:5
# /tmp/Data/genres_original/reggae/reggae.00055.wav, segment:6
# /tmp/Data/genres_original/reggae/reggae.00071.wav, segment:1
# /tmp/Data/genres_original/reggae/reggae.00071.wav, segment:2
# /tmp/Data/genres_original/reggae/reggae.00071.wav, segment:3
# /tmp/Data/genres_original/reggae/reggae.00071.wav, segment:4
# /tmp/Data/genres_original/reggae/reggae.
wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00017.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00017.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00017.wav, segment:6
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:1
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:2
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00012.wav, segment:6
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:1
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:2
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00094.wav, segment:6
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:1
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:2
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00044.wav, segment:6
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:1
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:2
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00057.wav, segment:6
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:1
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:2
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:3
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:4
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:5
# /tmp/Data/genres_original/jazz/jazz.00011.wav, segment:6

# %%
DATA_PATH = "/content/data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    z = np.array(data['mapping'])
    return X, y, z


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    :return z : Mappings for data
    """

    # load data
    X, y, z = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test, z


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dropout(0.3))
    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)
    
    # get mappings for target and predicted label
    target = z[y]
    predicted = z[predicted_index]

    print("Target: {}, Predicted label: {}".format(target, predicted))

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
X_train, X_validation, X_test, y_train, y_validation, y_test, z = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.Adam(lr=1e-8)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])

history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=128, epochs=100,callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 29/29 [==============================] - 2s 52ms/step - loss: 2.9843 - accuracy: 0.0890 - val_loss: 3.5423 - val_accuracy: 0.0857 - lr: 1.0000e-08
# Epoch 2/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9957 - accuracy: 0.0885 - val_loss: 2.9173 - val_accuracy: 0.0790 - lr: 1.1220e-08
# Epoch 3/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9860 - accuracy: 0.0946 - val_loss: 2.7206 - val_accuracy: 0.0701 - lr: 1.2589e-08
# Epoch 4/100
# 29/29 [==============================] - 1s 31ms/step - loss: 2.9735 - accuracy: 0.0985 - val_loss: 2.6569 - val_accuracy: 0.0756 - lr: 1.4125e-08
# Epoch 5/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9896 - accuracy: 0.0862 - val_loss: 2.6378 - val_accuracy: 0.0801 - lr: 1.5849e-08
# Epoch 6/100
# 29/29 [==============================] - 1s 31ms/step - loss: 2.9938 - accuracy: 0.0974 - val_loss: 2.6357 - val_accuracy: 0.0756 - lr: 1.7783e-08
# Epoch 7/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9914 - accuracy: 0.0873 - val_loss: 2.6413 - val_accuracy: 0.0690 - lr: 1.9953e-08
# Epoch 8/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9858 - accuracy: 0.0926 - val_loss: 2.6509 - val_accuracy: 0.0667 - lr: 2.2387e-08
# Epoch 9/100
# 29/29 [==============================] - 1s 30ms/step - loss: 3.0053 - accuracy: 0.0904 - val_loss: 2.6621 - val_accuracy: 0.0645 - lr: 2.5119e-08
# Epoch 10/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9968 - accuracy: 0.0926 - val_loss: 2.6741 - val_accuracy: 0.0667 - lr: 2.8184e-08
# Epoch 11/100
# 29/29 [==============================] - 1s 31ms/step - loss: 2.9795 - accuracy: 0.1013 - val_loss: 2.6853 - val_accuracy: 0.0667 - lr: 3.1623e-08
# Epoch 12/100
# 29/29 [==============================] - 1s 30ms/step - loss: 3.0052 - accuracy: 0.0809 - val_loss: 2.6963 - val_accuracy: 0.0634 - lr: 3.5481e-08
# Epoch 13/100
# 29/29 [==============================] - 1s 30ms/step - loss: 3.0054 - accuracy: 0.0879 - val_loss: 2.7057 - val_accuracy: 0.0634 - lr: 3.9811e-08
# Epoch 14/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.9998 - accuracy: 0.0879 - val_loss: 2.7134 - val_accuracy: 0.0645 - lr: 4.4668e-08
# Epoch 15/100
# 29/29 [==============================] - 1s 30ms/step - loss: 2.
100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9944 - accuracy: 0.6512 - val_loss: 1.1595 - val_accuracy: 0.5628 - lr: 2.2387e-04
# Epoch 89/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9349 - accuracy: 0.6729 - val_loss: 1.1116 - val_accuracy: 0.5784 - lr: 2.5119e-04
# Epoch 90/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.9140 - accuracy: 0.6860 - val_loss: 1.1572 - val_accuracy: 0.5617 - lr: 2.8184e-04
# Epoch 91/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8589 - accuracy: 0.6985 - val_loss: 1.2377 - val_accuracy: 0.5517 - lr: 3.1623e-04
# Epoch 92/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.8351 - accuracy: 0.7093 - val_loss: 1.3219 - val_accuracy: 0.5328 - lr: 3.5481e-04
# Epoch 93/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.8142 - accuracy: 0.7113 - val_loss: 1.0148 - val_accuracy: 0.6274 - lr: 3.9811e-04
# Epoch 94/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7680 - accuracy: 0.7302 - val_loss: 1.1267 - val_accuracy: 0.6363 - lr: 4.4668e-04
# Epoch 95/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7339 - accuracy: 0.7410 - val_loss: 1.0888 - val_accuracy: 0.6274 - lr: 5.0119e-04
# Epoch 96/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6820 - accuracy: 0.7602 - val_loss: 1.2870 - val_accuracy: 0.5651 - lr: 5.6234e-04
# Epoch 97/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6313 - accuracy: 0.7766 - val_loss: 1.0764 - val_accuracy: 0.6352 - lr: 6.3096e-04
# Epoch 98/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5998 - accuracy: 0.7889 - val_loss: 1.2709 - val_accuracy: 0.5717 - lr: 7.0795e-04
# Epoch 99/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5829 - accuracy: 0.7939 - val_loss: 1.6560 - val_accuracy: 0.5206 - lr: 7.9433e-04
# Epoch 100/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5976 - accuracy: 0.7972 - val_loss: 0.9318 - val_accuracy: 0.6930 - lr: 8.9125e-04

# %%
plt.semilogx(history.history["lr"], history.history["val_loss"])
plt.axis([1e-8, 1e-3, 0, 5])
# Out:
# (1e-08, 0.001, 0.0, 5.0)

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

optimizer = tf.keras.optimizers.Adam(lr=6e-5)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=128, epochs=200)

plot_history(history)

# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/200
# 29/29 [==============================] - 1s 39ms/step - loss: 2.6613 - accuracy: 0.1227 - val_loss: 3.0551 - val_accuracy: 0.1012
# Epoch 2/200
# 29/29 [==============================] - 1s 31ms/step - loss: 2.1955 - accuracy: 0.2156 - val_loss: 2.2554 - val_accuracy: 0.1858
# Epoch 3/200
# 29/29 [==============================] - 1s 32ms/step - loss: 1.9557 - accuracy: 0.3082 - val_loss: 2.0062 - val_accuracy: 0.2592
# Epoch 4/200
# 29/29 [==============================] - 1s 32ms/step - loss: 1.8033 - accuracy: 0.3588 - val_loss: 1.8788 - val_accuracy: 0.3482
# Epoch 5/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.7154 - accuracy: 0.3725 - val_loss: 1.7769 - val_accuracy: 0.3882
# Epoch 6/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.6103 - accuracy: 0.4270 - val_loss: 1.7013 - val_accuracy: 0.4138
# Epoch 7/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.5502 - accuracy: 0.4348 - val_loss: 1.6157 - val_accuracy: 0.4305
# Epoch 8/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.4842 - accuracy: 0.4670 - val_loss: 1.5593 - val_accuracy: 0.4538
# Epoch 9/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.4523 - accuracy: 0.4679 - val_loss: 1.5112 - val_accuracy: 0.4694
# Epoch 10/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.4024 - accuracy: 0.4818 - val_loss: 1.4676 - val_accuracy: 0.4727
# Epoch 11/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.3504 - accuracy: 0.5102 - val_loss: 1.4247 - val_accuracy: 0.4839
# Epoch 12/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.3343 - accuracy: 0.5171 - val_loss: 1.3945 - val_accuracy: 0.5006
# Epoch 13/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.2881 - accuracy: 0.5396 - val_loss: 1.3521 - val_accuracy: 0.4983
# Epoch 14/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.2501 - accuracy: 0.5577 - val_loss: 1.3264 - val_accuracy: 0.5061
# Epoch 15/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.2216 - accuracy: 0.5666 - val_loss: 1.3112 - val_accuracy: 0.5195
# Epoch 16/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1914 - accuracy: 0.5733 - val_loss: 1.3033 - val_accuracy: 0.5095
# Epoch 17/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1766 - accuracy: 0.5828 - val_loss: 1.2774 - val_accuracy: 0.5250
# Epoch 18/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1488 - accuracy: 0.5900 - val_loss: 1.2353 - val_accuracy: 0.5439
# Epoch 19/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1316 - accuracy: 0.5914 - val_loss: 1.2379 - val_accuracy: 0.5317
# Epoch 20/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1018 - accuracy: 0.6131 - val_loss: 1.2201 - val_accuracy: 0.5417
# Epoch 21/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.0817 - accuracy: 0.6128 - val_loss: 1.1903 - val_accuracy: 0.5584
# Epoch 22/200
# 29/29 [==============================] - 1s 30ms/step - loss: 1.0642 - accuracy: 0.6245 - val_loss: 1.1836 - val_accuracy: 0.5584
# Epoch 23/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.0367 - accuracy: 0.6350 - val_loss: 1.1759 - val_accuracy: 0.5562
# Epoch 24/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.0274 - accuracy: 0.6412 - val_loss: 1.1422 - val_accuracy: 0.5751
# Epoch 25/200
# 29/29 [==============================] - 1s 31ms/step - loss: 1.0070 - accuracy: 0.6414 - val_loss: 1.1365 - val_accuracy: 0.5762
# Epoch 26/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.9958 - accuracy: 0.6526 - val_loss: 1.1221 - val_accuracy: 0.5851
# Epoch 27/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9669 - accuracy: 0.6634 - val_loss: 1.1219 - val_accuracy: 0.5784
# Epoch 28/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.9610 - accuracy: 0.6698 - val_loss: 1.1158 - val_accuracy: 0.5840
# Epoch 29/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9439 - accuracy: 0.6606 - val_loss: 1.1029 - val_accuracy: 0.5918
# Epoch 30/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9222 - accuracy: 0.6823 - val_loss: 1.0885 - val_accuracy: 0.6085
# Epoch 31/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.9132 - accuracy: 0.6740 - val_loss: 1.0704 - val_accuracy: 0.6107
# Epoch 32/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.8985 - accuracy: 0.6815 - val_loss: 1.0624 - val_accuracy: 0.6140
# Epoch 33/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8838 - accuracy: 0.6865 - val_loss: 1.0551 - val_accuracy: 0.6118
# Epoch 34/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8617 - accuracy: 0.6943 - val_loss: 1.0440 - val_accuracy: 0.6218
# Epoch 35/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8551 - accuracy: 0.6976 - val_loss: 1.0360 - val_accuracy: 0.6307
# Epoch 36/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.8350 - accuracy: 0.7043 - val_loss: 1.0253 - val_accuracy: 0.6396
# Epoch 37/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8228 - accuracy: 0.7221 - val_loss: 1.0191 - val_accuracy: 0.6385
# Epoch 38/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8209 - accuracy: 0.7127 - val_loss: 0.9983 - val_accuracy: 0.6429
# Epoch 39/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0
200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1643 - accuracy: 0.9561 - val_loss: 0.7653 - val_accuracy: 0.7597
# Epoch 163/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1630 - accuracy: 0.9574 - val_loss: 0.7816 - val_accuracy: 0.7597
# Epoch 164/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1573 - accuracy: 0.9599 - val_loss: 0.7589 - val_accuracy: 0.7731
# Epoch 165/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1660 - accuracy: 0.9544 - val_loss: 0.7435 - val_accuracy: 0.7764
# Epoch 166/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1517 - accuracy: 0.9591 - val_loss: 0.7739 - val_accuracy: 0.7664
# Epoch 167/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1495 - accuracy: 0.9619 - val_loss: 0.7193 - val_accuracy: 0.7798
# Epoch 168/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1540 - accuracy: 0.9599 - val_loss: 0.8074 - val_accuracy: 0.7586
# Epoch 169/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1607 - accuracy: 0.9541 - val_loss: 0.7911 - val_accuracy: 0.7608
# Epoch 170/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1546 - accuracy: 0.9586 - val_loss: 0.7379 - val_accuracy: 0.7798
# Epoch 171/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1540 - accuracy: 0.9588 - val_loss: 0.7171 - val_accuracy: 0.7842
# Epoch 172/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1538 - accuracy: 0.9533 - val_loss: 0.7576 - val_accuracy: 0.7642
# Epoch 173/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1486 - accuracy: 0.9588 - val_loss: 0.7776 - val_accuracy: 0.7709
# Epoch 174/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1501 - accuracy: 0.9599 - val_loss: 0.7762 - val_accuracy: 0.7764
# Epoch 175/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1475 - accuracy: 0.9599 - val_loss: 0.7820 - val_accuracy: 0.7631
# Epoch 176/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1477 - accuracy: 0.9624 - val_loss: 0.7661 - val_accuracy: 0.7709
# Epoch 177/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1434 - accuracy: 0.9605 - val_loss: 0.7469 - val_accuracy: 0.7786
# Epoch 178/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1410 - accuracy: 0.9655 - val_loss: 0.7938 - val_accuracy: 0.7608
# Epoch 179/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1428 - accuracy: 0.9619 - val_loss: 0.7431 - val_accuracy: 0.7809
# Epoch 180/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1469 - accuracy: 0.9591 - val_loss: 0.7279 - val_accuracy: 0.7809
# Epoch 181/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1284 - accuracy: 0.9688 - val_loss: 0.7493 - val_accuracy: 0.7709
# Epoch 182/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1351 - accuracy: 0.9630 - val_loss: 0.7418 - val_accuracy: 0.7753
# Epoch 183/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1233 - accuracy: 0.9697 - val_loss: 0.7511 - val_accuracy: 0.7720
# Epoch 184/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1394 - accuracy: 0.9644 - val_loss: 0.7290 - val_accuracy: 0.7764
# Epoch 185/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1370 - accuracy: 0.9652 - val_loss: 0.7585 - val_accuracy: 0.7798
# Epoch 186/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1358 - accuracy: 0.9650 - val_loss: 0.7481 - val_accuracy: 0.7798
# Epoch 187/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1350 - accuracy: 0.9630 - val_loss: 0.7539 - val_accuracy: 0.7786
# Epoch 188/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1355 - accuracy: 0.9661 - val_loss: 0.8412 - val_accuracy: 0.7486
# Epoch 189/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1179 - accuracy: 0.9725 - val_loss: 0.7377 - val_accuracy: 0.7775
# Epoch 190/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1228 - accuracy: 0.9697 - val_loss: 0.7572 - val_accuracy: 0.7809
# Epoch 191/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1295 - accuracy: 0.9661 - val_loss: 0.7704 - val_accuracy: 0.7697
# Epoch 192/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1248 - accuracy: 0.9669 - val_loss: 0.7490 - val_accuracy: 0.7786
# Epoch 193/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1240 - accuracy: 0.9702 - val_loss: 0.7871 - val_accuracy: 0.7564
# Epoch 194/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1158 - accuracy: 0.9722 - val_loss: 0.7591 - val_accuracy: 0.7675
# Epoch 195/200
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1122 - accuracy: 0.9733 - val_loss: 0.7687 - val_accuracy: 0.7697
# Epoch 196/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1347 - accuracy: 0.9641 - val_loss: 0.7475 - val_accuracy: 0.7831
# Epoch 197/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1172 - accuracy: 0.9702 - val_loss: 0.7424 - val_accuracy: 0.7853
# Epoch 198/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1106 - accuracy: 0.9744 - val_loss: 0.7709 - val_accuracy: 0.7720
# Epoch 199/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1201 - accuracy: 0.9691 - val_loss: 0.8194 - val_accuracy: 0.7575
# Epoch 200/200
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1085 - accuracy: 0.9772 - val_loss: 0.7358 - val_accuracy: 0.7764
# 47/47 - 0s - loss: 0.8564 - accuracy: 0.7570
#
# Test accuracy: 0.7570093274116516

# %%
for i in range(X_test.shape[0]):
    X_to_predict = X_test[i]
    y_to_predict = y_test[i]

    predict(model, X_to_predict, y_to_predict)
# Out:
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['pop']
# Target: country, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['country']
# Target: country, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['classical']
# Target: disco, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['metal']
# Target: jazz, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['country']
# Target: hiphop, Predicted label: ['pop']
# Target: rock, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['pop']
# Target: country, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['rock']
# Target: disco, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['country']
# Target: country, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['country']
# Target: jazz, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: country, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['country']
# Target: reggae, Predicted label: ['disco']
# Target: blues, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['disco']
# Target: country, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['reggae']
# Target: rock, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['pop']
# Target: reggae, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['disco']
# Target: disco, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['country']
# Target: classical, Predicted label: ['blues']
# Target: jazz, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['jazz']
# Target: disco, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['disco']
# Target: jazz, Predicted label: ['pop']
# Target: jazz, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['rock']
# Target: jazz, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['pop']
# Target: disco, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['country']
# Target: rock, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['rock']
# Target: jazz, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['reggae']
# Target: pop, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['rock']
# Target: classical, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['disco']
# Target: blues, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['reggae']
# Target: classical, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['blues']
# Target: rock, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['blues']
# Target: blues, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: blues, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['blues']
# Target: reggae, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['rock']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# ...
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['rock']
# Target: country, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: classical, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: hiphop, Predicted label: ['hiphop']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['metal']
# Target: metal, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['rock']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: country, Predicted label: ['blues']
# Target: metal, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['pop']
# Target: disco, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['rock']
# Target: reggae, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['disco']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['country']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: rock, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: disco, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['pop']
# Target: disco, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: rock, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['disco']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['metal']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['hiphop']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: country, Predicted label: ['country']
# Target: country, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['country']
# Target: reggae, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['hiphop']
# Target: jazz, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['reggae']
# Target: classical, Predicted label: ['country']
# Target: rock, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: hiphop, Predicted label: ['reggae']
# Target: pop, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: jazz, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['disco']
# Target: classical, Predicted label: ['classical']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: metal, Predicted label: ['metal']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['hiphop']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['disco']
# Target: country, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['disco']
# Target: reggae, Predicted label: ['hiphop']
# Target: reggae, Predicted label: ['reggae']
# Target: hiphop, Predicted label: ['hiphop']
# Target: classical, Predicted label: ['classical']
# Target: hiphop, Predicted label: ['blues']
# Target: disco, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['reggae']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: reggae, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: rock, Predicted label: ['country']
# Target: classical, Predicted label: ['rock']
# Target: metal, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['rock']
# Target: rock, Predicted label: ['blues']
# Target: hiphop, Predicted label: ['reggae']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: rock, Predicted label: ['rock']
# Target: disco, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['rock']
# Target: blues, Predicted label: ['rock']
# Target: hiphop, Predicted label: ['reggae']
# Target: rock, Predicted label: ['country']
# Target: country, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: blues, Predicted label: ['blues']
# Target: disco, Predicted label: ['rock']
# Target: rock, Predicted label: ['disco']
# Target: rock, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: pop, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: jazz, Predicted label: ['jazz']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['metal']
# Target: classical, Predicted label: ['classical']
# Target: reggae, Predicted label: ['reggae']
# Target: rock, Predicted label: ['reggae']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: hiphop, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['blues']
# Target: pop, Predicted label: ['pop']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['metal']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['country']
# Target: country, Predicted label: ['country']
# Target: hiphop, Predicted label: ['hiphop']
# Target: rock, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: disco, Predicted label: ['disco']
# Target: blues, Predicted label: ['blues']
# Target: rock, Predicted label: ['pop']
# Target: rock, Predicted label: ['country']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: metal, Predicted label: ['metal']
# Target: metal, Predicted label: ['rock']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['jazz']
# Target: pop, Predicted label: ['pop']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['blues']
# Target: metal, Predicted label: ['metal']
# Target: blues, Predicted label: ['blues']
# Target: classical, Predicted label: ['classical']
# Target: country, Predicted label: ['country']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: jazz, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: pop, Predicted label: ['pop']
# Target: jazz, Predicted label: ['jazz']
# Target: classical, Predicted label: ['classical']
# Target: disco, Predicted label: ['disco']
# Target: reggae, Predicted label: ['reggae']
# Target: metal, Predicted label: ['metal']
# Target: country, Predicted label: ['blues']
# Target: reggae, Predicted label: ['reggae']
# Target: classical, Predicted label: ['classical']
# Target: blues, Predicted label: ['blues']
# Target: country, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: blues, Predicted label: ['country']
# Target: pop, Predicted label: ['pop']
# Target: hiphop, Predicted label: ['reggae']
# Target: rock, Predicted label: ['rock']
# Target: rock, Predicted label: ['country']
# Target: jazz, Predicted label: ['jazz']
# Target: reggae, Predicted label: ['reggae']
# Target: blues, Predicted label: ['blues']

# %%
model.save("modelnew2.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model_json = model.to_json()
with open("model1.json", "w") as json_file:
    json_file.write(model_json)

# %%
from keras.models import load_model 
keras_file ="modelnew2.h5" 
keras.models.save_model(model,keras_file)
from tensorflow import lite 
coverter = tf.compat.v1.lite.TFLiteConverter.from_keras_model_file(keras_file)
# Out:
# Using TensorFlow backend.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TF Lite model.
with tf.io.gfile.GFile('model1.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
interpreter = tf.lite.Interpreter(model_path="model1.tflite")
interpreter.allocate_tensors()

print(interpreter.get_input_details()[0]['shape'])  
print(interpreter.get_input_details()[0]['dtype']) 

print(interpreter.get_output_details()[0]['shape'])  
print(interpreter.get_output_details()[0]['dtype'])
# Out:
# [  1 216  13   1]
# <class 'numpy.float32'>
# [ 1 10]
# <class 'numpy.float32'>

# %%
input_index= interpreter.get_input_details()
print(input_index)
#output_details = interpreter.get_output_details()
output_index = interpreter.get_output_details()
print(output_index)
# Out:
# [{'name': 'conv2d_input', 'index': 0, 'shape': array([  1, 216,  13,   1], dtype=int32), 'shape_signature': array([  1, 216,  13,   1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [{'name': 'Identity', 'index': 33, 'shape': array([ 1, 10], dtype=int32), 'shape_signature': array([ 1, 10], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
